# %%
import logging
from logging.handlers import RotatingFileHandler
import requests
import pandas as pd
import os

# Create the directory if it doesn't exist
log_dir = r'C:\Users\mohan\OneDrive\Documents\MS\CGS 2100\POC\log'
if not os.path.exists(log_dir):
    os.makedirs(log_dir)

# Configure logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

# Create a file handler
file_handler = RotatingFileHandler(os.path.join(log_dir, 'api_log.log'), maxBytes=100000, backupCount=3)
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(logging.Formatter('%(asctime)s - %(levelname)s - %(message)s'))

# Add the file handler to the root logger
logging.getLogger().addHandler(file_handler)

def fetch_data(api_url, headers):
    response = requests.get(api_url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        logging.error(f"Failed to fetch data from API. Status code: {response.status_code}")
        return None

def get_all_data(api_url, headers):
    all_data = []
    api_calls = 0  # Initialize counter for API calls
    while True:  # Continue looping until there are no more records
        response = requests.get(api_url, headers=headers)
        api_calls += 1  # Increment API call counter
        if response.status_code == 200:
            data = response.json()
            all_data.extend(data)
            if 'next' in response.links:
                next_url = response.links['next']['url']
                api_url = next_url
            else:
                logging.info("No more records to retrieve. Stopping pagination.")
                break  # Exit the loop if there are no more pages
        else:
            logging.error(f"Failed to fetch data from API. Status code: {response.status_code}")
            break  # Exit the loop if the API request fails
    logging.info(f"API called {api_calls} times")  # Log API call count
    return all_data


def main():
    # Define API URL and bearer token
    api_url = "https://usflearn.instructure.com/api/v1/courses/1857108/enrollments"
    bearer_token = "13~D9Rs8zX2eEumEXC0knPDXdIXQLbq4cKVwVnYGmBYEgBFPMI2Yu1suCAk1l1E90Uq"

    # Define headers with bearer token authentication
    headers = {"Authorization": f"Bearer {bearer_token}"}

    # Fetch all data from the API
    all_data = get_all_data(api_url, headers)

    # Convert data to DataFrame
    if all_data:
        df = pd.DataFrame(all_data)
        logging.info("Data fetched successfully and saved to DataFrame.")

        # Save DataFrame to Excel file
        file_path = r"C:\Users\mohan\OneDrive\Documents\MS\CGS 2100\POC\enrollments_data1.xlsx"
        df.to_excel(file_path, index=False)  # Index=False to exclude row numbers

        logging.info(f"Data saved to '{file_path}'.")
        print(df.head())  # Display the first few rows of the DataFrame
    else:
        logging.warning("No data fetched from the API.")

if __name__ == "__main__":
    main()
# Out:
# 2024-04-18 15:40:28,463 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:30,924 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments HTTP/1.1" 200 None
# 2024-04-18 15:40:30,932 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:32,473 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkFkZWxtYW4sIFRheWxvciIsNDIyODUyMjNd&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:40:32,489 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:33,932 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkFsbW9uLCBKYWlkZW4iLDQyMjYzMDM5XQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:40:33,943 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:35,246 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkFuZGVyc29uLCBCZW5qYW1pbiIsNDI0NTM2MDFd&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:40:35,254 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:36,593 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkFzaGxleSwgVGhvbWFzIiw0MjAzNDg2N10&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:40:36,601 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:38,208 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkJhaXJkLCBNYWRpbHlubiIsNDIyOTQ2MzFd&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:40:38,223 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:39,553 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkJhdGlzdGEsIEx1aXMiLDQyMzg1MDg3XQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:40:39,571 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:40,855 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkJsYW5jLCBKZW5pcXVlIiw0MjI1Nzc4N10&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:40:40,861 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:42,182 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkJyZW1vbnQsIFR5bGVyIiw0MjUwOTA0N10&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:40:42,198 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:43,559 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkJ1cm5ldHQsIEtlZGlzdCIsNDI2MTE4NzNd&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:40:43,569 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:44,867 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkNhdmFuLCBUcmF2aXMiLDQyMzIwNzAzXQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:40:44,875 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:46,323 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkNobywgQ2hyaXN0aWFuIiw0MjI5NTc1N10&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:40:46,336 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:47,608 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkNvaG4sIFBhaWdlIiw0MjE4MTI1OV0&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:40:47,632 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:49,093 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkNvc3RhIERhIFNpbHZhLCBBbGxhbiBKdW5pb3IiLDQyMjU5OTc1XQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:40:49,101 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:50,331 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkN1YmlsbG9zLCBCcmFuZG9uIiw0MjM4MjI0NV0&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:40:50,341 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:51,851 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkRhbWlhbmFraXMsIEFuYXN0YXNpb3MiLDQyMjYzMDA5XQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:40:51,858 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:53,168 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkRlbGFuZXksIFNlYW4iLDQyMjk3NTI1XQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:40:53,177 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:54,493 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkRpc2Fycm8sIEVtbWEiLDQyNTk3NDc1XQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:40:54,501 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:55,869 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkRyYXBlciwgSGFsZXkiLDQyMjkyMjMzXQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:40:55,877 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:57,127 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkVsbGVuYmFjaywgTHVrZSIsNDIzNDM2MjFd&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:40:57,135 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:58,431 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkZlcmd1c29uLCBSJ1JlbGxlIiw0MjM0NTAyM10&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:40:58,442 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:40:59,896 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkdhYmVyc2VjaywgUHJlc2xleSIsNDIzMzc3ODdd&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:40:59,905 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:01,378 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkdhc3RlbCwgSm9yZGFuIiw0MjI2ODI2NV0&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:01,387 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:02,623 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkdsYXplLCBDaHJpc3RpbmEiLDQxOTk2Mzk3XQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:02,631 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:04,028 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkdvdWJza2ksIEl2YW4iLDQyMjk4MTMzXQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:04,045 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:05,366 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkhhZGRhYmVoLCBMYXlsYSIsNDIwNjIyMzNd&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:05,390 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:06,594 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkhhcnJpcywgRWxpamFoIiw0MjMwODYzMV0&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:06,594 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:07,821 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkhlcm5hbmRleiwgQWxlamFuZHJvIiw0MjM4NjA0N10&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:07,837 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:09,033 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkhvZ2x1bmQsIENvbm5vciIsNDI2OTU2ODld&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:09,048 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:10,386 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkh1YW5nLCBZdXhpbiIsNDIwNTU3NTdd&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:10,386 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:11,695 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkphY2tzb24sIEpvc2VwaCIsNDI2NDA4NTld&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:11,708 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:13,045 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkpvbmVzLCBTYW1hbnRoYSIsNDIzNDU5ODdd&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:13,045 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:14,272 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIktlcmRwaG9raGEsIFNvaXN1ZGEiLDQyNDMzMDU3XQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:14,287 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:15,578 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIktvZXJuZXIsIENhc2V5Iiw0MjI0NjEyNV0&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:15,595 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:16,935 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkt1cGlzLCBWaWN0b3JpYSIsNDI3MzM3ODld&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:16,935 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:18,225 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkxlZGVybWFuLCBJbGFuIiw0MjI5NDY5M10&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:18,241 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:19,499 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkxpdmluZ3N0b24sIEVyZW5hIiw0MjcyMjE4MV0&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:19,507 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:20,886 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIk1hYmlsdSwgTWJpbHUiLDQyMjc3MzA1XQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:20,886 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:22,163 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIk1hc29uLCBQcmVzbGV5Iiw0MjQ0MDU2MV0&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:22,163 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:23,407 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIk1jY2x1cmUsIEFubmEiLDQyMjg2MTU5XQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:23,423 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:25,025 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIk1ldXNoYXcsIEphY2siLDQyNjE4MzI1XQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:25,036 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:26,472 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIk1vbGluYSBNZWRpbmEsIFJvYWxleCIsNDI0MTIwNjNd&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:26,487 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:27,885 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIk1vcmFuLCBBdmEiLDQyMDA1MjAzXQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:27,901 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:29,525 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIk5hcmVzaCwgTGFrc2htaSIsNDIxNTE3NTld&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:29,546 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:30,955 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIk5ndXllbiwgSmFjZXkiLDQyMzk4NDcxXQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:30,971 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:32,261 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIk5pdHRpLCBKb2huIiw0MjIwNzg2OV0&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:32,277 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:33,632 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIk9saXZlaXJhIE1vbnRlaXJvIERlIFBhdWxhLCBKb2FvIFBlZHJvIiw0MjMyNDMwNV0&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:33,632 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:34,875 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIk90dGVuLCBHcmVnb3J5Iiw0MjA0ODUwOV0&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:34,891 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:36,090 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIlBhdGVsLCBLZWFudSIsNDIzODA4ODNd&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:36,099 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:37,614 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIlBlZXJ6YWRhLCBCdXJoYW4gVSBEaW4iLDQyMzEwMzY3XQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:37,629 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:38,920 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIlBpZXJyZS1Mb3VpcywgQ2hyaXN0aWUiLDQyNzI2NDQ5XQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:38,936 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:40,273 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIlByYWJodSwgS2FydGhpayIsNDIyNzM4NTld&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:40,289 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:41,613 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIlJhbWlhaCwgRGF2b24iLDQyMjU2NzEzXQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:41,613 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:42,921 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIlJlc2VuZGUgWmFrdXIsIEdhYnJpZWxhIiw0MjI5Nzk3MV0&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:42,921 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:44,276 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIlJvZHJpZ3VleiwgTWlhIiw0MjI4NzkwNV0&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:44,290 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:45,611 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIlJ1dGhlcmZvcmQsIFJ5YW4iLDQyMDMzMjk1XQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:45,627 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:46,950 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIlNhbnRvcywgU2ViYXN0aWFuIiw0MjM0ODI4M10&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:46,950 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:48,272 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIlNoYWh6YWQsIEFyaGFtIiw0MjI2MjgzNV0&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:48,286 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:49,551 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIlNpbXBsaWNlLCBKb25hdGhhbiIsNDIzMDQ1MjVd&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:49,567 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:50,735 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIlNuYWhhLCBNb29udGFrYSBBaG1lZCIsNDI0NTU5OTVd&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:50,750 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:52,055 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIlN0ZWluYmVyZywgQWlkYW4iLDQyMzQ2NzIzXQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:52,071 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:53,803 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIlRhaWxvciwgS3Jpc2giLDQyMjcwODA3XQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:53,803 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:55,061 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIlRob21hcywgTWlsZXMiLDQyMzQ4MTExXQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:55,061 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:56,286 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIlRvbmV5LCBHcmFudCIsNDIxNTE4NTld&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:56,303 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:57,529 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIlRyZWxsYSwgRW1pbHkiLDQyMzcwNjg3XQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:57,545 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:41:58,818 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIlZhbGxlYnVvbmEsIFRpYWdvIiw0MjM3OTk0MV0&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:41:58,834 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:42:00,076 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIlZpbGxhZmFuYSwgTWlhIiw0MjI1NzY5MV0&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:42:00,092 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:42:01,310 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIldhbHNlciwgQ29ubm9yIiw0MjA4ODU1MV0&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:42:01,320 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:42:02,610 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIldlaW5lciwgU2FtYW50aGEiLDQyNDA5MTM1XQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:42:02,614 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:42:03,931 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIldpbHRvbiwgRXJpY2EiLDQyMjEyNzE5XQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:42:03,947 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:42:05,157 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIlplaWtvd2l0eiwgSmFjb2IiLDQyNDYyNzQ1XQ&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:42:05,173 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:42:06,194 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50Vmlld0Vucm9sbG1lbnQiLCJTdHVkZW50LCBUZXN0Iiw0MjY0NDUwNV0&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:42:06,194 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:42:07,452 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50Vmlld0Vucm9sbG1lbnQiLCJTdHVkZW50LCBUZXN0Iiw0MjY0NDUyNV0&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:42:07,468 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:42:08,333 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJUZWFjaGVyRW5yb2xsbWVudCIsIldhbHBvbGUgKEFkbWluKSwgRGVubmlzIiw0MTkzOTIzMV0&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:42:08,349 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-04-18 15:42:09,151 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJUZWFjaGVyRW5yb2xsbWVudCIsIldhbHBvbGUgKEFkbWluKSwgRGVubmlzIiw0MTkzOTM4NV0&per_page=10 HTTP/1.1" 200 None
# 2024-04-18 15:42:09,166 - INFO - No more records to retrieve. Stopping pagination.
# 2024-04-18 15:42:09,166 - INFO - API called 75 times
# 2024-04-18 15:42:09,182 - INFO - Data fetched successfully and saved to DataFrame.
# 2024-04-18 15:42:10,549 - INFO - Data saved to 'C:\Users\mohan\OneDrive\Documents\MS\CGS 2100\POC\enrollments_data1.xlsx'.
#          id  user_id  course_id                type            created_at  \
# 0  42697283  4638795    1857108  DesignerEnrollment  2024-01-08T20:22:12Z
# 1  42066599  4959011    1857108   StudentEnrollment  2023-10-31T05:42:10Z
# 2  42337449  4940043    1857108   StudentEnrollment  2023-11-19T06:42:02Z
# 3  42449855  4836803    1857108   StudentEnrollment  2023-12-08T20:23:59Z
# 4  42050207  4853363    1857108   StudentEnrollment  2023-10-30T23:26:20Z
#
#              updated_at associated_user_id start_at end_at  course_section_id  \
# 0  2024-01-08T20:37:03Z               None     None   None            2039727
# 1  2023-12-12T19:57:37Z               None     None   None            2039735
# 2  2023-12-12T19:50:37Z               None     None   None            2039733
# 3  2023-12-12T19:53:30Z               None     None   None            2039741
# 4  2023-12-12T19:50:37Z               None     None   None            2039733
#
#    ...  total_activity_time  sis_account_id   sis_course_id  \
# 0  ...                  423          BU.ISM  CGS2100.001S24
# 1  ...                 6831          BU.ISM  CGS2100.001S24
# 2  ...                32172          BU.ISM  CGS2100.001S24
# 3  ...                28199          BU.ISM  CGS2100.001S24
# 4  ...                15372          BU.ISM  CGS2100.001S24
#
#   course_integration_id  sis_section_id section_integration_id sis_user_id  \
# 0                  None  CGS2100.001S24                   None   U64940243
# 1                  None  CGS2100.008S24                   None   U87546613
# 2                  None  CGS2100.006S24                   None   U30443576
# 3                  None  CGS2100.007S24                   None   U97733899
# 4                  None  CGS2100.006S24                   None   U67196743
#
#                                             html_url  \
# 0  https://usflearn.instructure.com/courses/18571...
# 1  https://usflearn.instructure.com/courses/18571...
# 2  https://usflearn.instructure.com/courses/18571...
# 3  https://usflearn.instructure.com/courses/18571...
# 4  https://usflearn.instructure.com/courses/18571...
#
#                                                 user  \
# 0  {'id': 4638795, 'name': 'Tess Crowder', 'creat...
# 1  {'id': 4959011, 'name': 'Janette Aarnio', 'cre...
# 2  {'id': 4940043, 'name': 'Taline Abadjian', 'cr...
# 3  {'id': 4836803, 'name': 'Trinity Abanid', 'cre...
# 4  {'id': 4853363, 'name': 'Steven Abdalla', 'cre...
#
#                                               grades
# 0                                                NaN
# 1  {'html_url': 'https://usflearn.instructure.com...
# 2  {'html_url': 'https://usflearn.instructure.com...
# 3  {'html_url': 'https://usflearn.instructure.com...
# 4  {'html_url': 'https://usflearn.instructure.com...
#
# [5 rows x 27 columns]

# %%
import pandas as pd
from ast import literal_eval
# Load the data from the Excel file
df = pd.read_excel(r'C:\Users\mohan\OneDrive\Documents\MS\CGS 2100\POC\enrollments_data1.xlsx')  # Replace with the path to your file
# Convert total activity time from seconds to hours
df['total_activity_time(in_hrs)'] = df['total_activity_time'] / 3600
# Define the columns to keep
columns_to_keep = [
    'user_id', 'type', 'role', 'last_activity_at',
    'total_activity_time(in_hrs)', 'sis_course_id', 'sis_section_id', 'sis_user_id', 'grades'
]
# Keep only the specified columns
df = df[columns_to_keep]
df.rename(columns={'user_id': 'Student ID'}, inplace=True)
# Check if 'grade' column exists to avoid KeyErrors
if 'grades' in df.columns:
    # Extract information from the 'grade' column if it contains a stringified dictionary
    df['grades'] = df['grades'].apply(lambda x: literal_eval(x) if not pd.isnull(x) and isinstance(x, str) else {})
    # Create new columns for each grade component
    grade_components = ['current_grade', 'current_score', 'final_grade', 'final_score',
                        'unposted_current_score', 'unposted_current_grade',
                        'unposted_final_score', 'unposted_final_grade']   
    for component in grade_components:
        df[component] = df['grades'].apply(lambda x: x.get(component))
    # Now you can drop the original 'grade' column
    df.drop('grades', axis=1, inplace=True)
# Save the cleaned DataFrame to a new Excel file
df.to_excel(r'C:\Users\mohan\OneDrive\Documents\MS\CGS 2100\POC\Processed Files\cleaned_enrollments_data.xlsx', index=False)  # Replace with your desired output path
# Print the first few rows to check the DataFrame
df.head()
# Out:
#    Student ID                type               role      last_activity_at  \
# 0     4638795  DesignerEnrollment      SAS Assistant  2024-01-10T17:30:48Z
# 1     4959011   StudentEnrollment  StudentEnrollment  2024-04-17T22:14:55Z
# 2     4940043   StudentEnrollment  StudentEnrollment  2024-04-18T18:40:15Z
# 3     4836803   StudentEnrollment  StudentEnrollment  2024-04-17T17:44:00Z
# 4     4853363   StudentEnrollment  StudentEnrollment  2024-04-18T16:57:59Z
#
#    total_activity_time(in_hrs)   sis_course_id  sis_section_id sis_user_id  \
# 0                     0.117500  CGS2100.001S24  CGS2100.001S24   U64940243
# 1                     1.897500  CGS2100.001S24  CGS2100.008S24   U87546613
# 2                     8.936667  CGS2100.001S24  CGS2100.006S24   U30443576
# 3                     7.833056  CGS2100.001S24  CGS2100.007S24   U97733899
# 4                     4.270000  CGS2100.001S24  CGS2100.006S24   U67196743
#
#   current_grade  current_score final_grade  final_score  \
# 0          None            NaN        None          NaN
# 1          None          99.68        None        89.59
# 2          None          97.31        None        87.58
# 3          None          83.19        None        74.87
# 4          None         101.23        None        91.11
#
#    unposted_current_score unposted_current_grade  unposted_final_score  \
# 0                     NaN                   None                   NaN
# 1                   99.68                   None                 89.59
# 2                   97.31                   None                 87.58
# 3                   83.19                   None                 74.87
# 4                  101.23                   None                 91.11
#
#   unposted_final_grade
# 0                 None
# 1                 None
# 2                 None
# 3                 None
# 4                 None

# %%
import pandas as pd
from ast import literal_eval
from datetime import datetime

# Load the data from the Excel file
df = pd.read_excel(r'C:\Users\mohan\OneDrive\Documents\MS\CGS 2100\POC\enrollments_data1.xlsx')  # Replace with the path to your file

# Convert 'last_activity_at' to datetime and make it timezone-naive
df['last_activity_at'] = pd.to_datetime(df['last_activity_at']).dt.tz_localize(None)

# Get the current date as timezone-naive
current_date = pd.to_datetime('today').tz_localize(None)

# Calculate inactivity days
df['inactive_days'] = (current_date - df['last_activity_at']).dt.days

# Replace negative values with 0 if 'last_activity_at' happens to be a future date
df['inactive_days'] = df['inactive_days'].apply(lambda x: max(x, 0))

# Convert total activity time from seconds to hours
df['total_activity_time(in_hrs)'] = df['total_activity_time'] / 3600

# Define the columns to keep
columns_to_keep = [
    'user_id', 'type', 'role', 'last_activity_at',
    'total_activity_time(in_hrs)', 'sis_course_id', 'sis_section_id', 'sis_user_id', 'grades','inactive_days'
]

# Keep only the specified columns
df = df[columns_to_keep]

# Rename the user_id column to Student ID
df.rename(columns={'user_id': 'Student ID'}, inplace=True)

# Process grades column if it exists
if 'grades' in df.columns:
    df['grades'] = df['grades'].apply(lambda x: literal_eval(x) if not pd.isnull(x) and isinstance(x, str) else {})
    
    grade_components = ['current_grade', 'current_score', 'final_grade', 'final_score',
                        'unposted_current_score', 'unposted_current_grade',
                        'unposted_final_score', 'unposted_final_grade']
    
    for component in grade_components:
        df[component] = df['grades'].apply(lambda x: x.get(component))
    
    # Drop the original 'grades' column
    df.drop('grades', axis=1, inplace=True)

# Save the cleaned DataFrame to a new Excel file
df.to_excel(r'C:\Users\mohan\OneDrive\Documents\MS\CGS 2100\POC\Processed Files\cleaned_enrollments_data.xlsx', index=False)

# Print the first few rows to verify
print(df.head())
# Out:
#    Student ID                type               role    last_activity_at  \
# 0     4638795  DesignerEnrollment      SAS Assistant 2024-01-10 17:30:48
# 1     4959011   StudentEnrollment  StudentEnrollment 2024-04-17 22:14:55
# 2     4940043   StudentEnrollment  StudentEnrollment 2024-04-18 18:40:15
# 3     4836803   StudentEnrollment  StudentEnrollment 2024-04-17 17:44:00
# 4     4853363   StudentEnrollment  StudentEnrollment 2024-04-18 16:57:59
#
#    total_activity_time(in_hrs)   sis_course_id  sis_section_id sis_user_id  \
# 0                     0.117500  CGS2100.001S24  CGS2100.001S24   U64940243
# 1                     1.897500  CGS2100.001S24  CGS2100.008S24   U87546613
# 2                     8.936667  CGS2100.001S24  CGS2100.006S24   U30443576
# 3                     7.833056  CGS2100.001S24  CGS2100.007S24   U97733899
# 4                     4.270000  CGS2100.001S24  CGS2100.006S24   U67196743
#
#    inactive_days current_grade  current_score final_grade  final_score  \
# 0             98          None            NaN        None          NaN
# 1              0          None          99.68        None        89.59
# 2              0          None          97.31        None        87.58
# 3              0          None          83.19        None        74.87
# 4              0          None         101.23        None        91.11
#
#    unposted_current_score unposted_current_grade  unposted_final_score  \
# 0                     NaN                   None                   NaN
# 1                   99.68                   None                 89.59
# 2                   97.31                   None                 87.58
# 3                   83.19                   None                 74.87
# 4                  101.23                   None                 91.11
#
#   unposted_final_grade
# 0                 None
# 1                 None
# 2                 None
# 3                 None
# 4                 None
