# %%
import logging
from logging.handlers import RotatingFileHandler
import requests
import pandas as pd
import os

# Create the directory if it doesn't exist
log_dir = r'C:\Users\nalla\Downloads\Mohan\log'
if not os.path.exists(log_dir):
    os.makedirs(log_dir)

# Configure logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

# Create a file handler
file_handler = RotatingFileHandler(os.path.join(log_dir, 'api_log.log'), maxBytes=100000, backupCount=3)
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(logging.Formatter('%(asctime)s - %(levelname)s - %(message)s'))

# Add the file handler to the root logger
logging.getLogger().addHandler(file_handler)

def fetch_data(api_url, headers):
    response = requests.get(api_url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        logging.error(f"Failed to fetch data from API. Status code: {response.status_code}")
        return None

def get_all_data(api_url, headers):
    all_data = []
    api_calls = 0  # Initialize counter for API calls
    while True:  # Continue looping until there are no more records
        response = requests.get(api_url, headers=headers)
        api_calls += 1  # Increment API call counter
        if response.status_code == 200:
            data = response.json()
            all_data.extend(data)
            if 'next' in response.links:
                next_url = response.links['next']['url']
                api_url = next_url
            else:
                logging.info("No more records to retrieve. Stopping pagination.")
                break  # Exit the loop if there are no more pages
        else:
            logging.error(f"Failed to fetch data from API. Status code: {response.status_code}")
            break  # Exit the loop if the API request fails
    logging.info(f"API called {api_calls} times")  # Log API call count
    return all_data


def main():
    # Define API URL and bearer token
    api_url = "https://usflearn.instructure.com/api/v1/courses/1857108/enrollments"
    bearer_token = "<Bearer_Token>"

    # Define headers with bearer token authentication
    headers = {"Authorization": f"Bearer {bearer_token}"}

    # Fetch all data from the API
    all_data = get_all_data(api_url, headers)

    # Convert data to DataFrame
    if all_data:
        df = pd.DataFrame(all_data)
        logging.info("Data fetched successfully and saved to DataFrame.")

        # Save DataFrame to Excel file
        file_path = r"C:\Users\nalla\Downloads\Mohan\data1.xlsx"
        df.to_excel(file_path, index=False)  # Index=False to exclude row numbers

        logging.info(f"Data saved to '{file_path}'.")
        print(df.head())  # Display the first few rows of the DataFrame
    else:
        logging.warning("No data fetched from the API.")

if __name__ == "__main__":
    main()
# Out:
# 2024-03-29 15:58:45,610 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-03-29 15:58:46,114 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments HTTP/1.1" 200 None
# 2024-03-29 15:58:46,121 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-03-29 15:58:46,727 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkFkZWxtYW4sIFRheWxvciIsNDIyODUyMjNd&per_page=10 HTTP/1.1" 200 None
# 2024-03-29 15:58:46,736 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-03-29 15:58:47,343 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkFsbW9uLCBKYWlkZW4iLDQyMjYzMDM5XQ&per_page=10 HTTP/1.1" 200 None
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\nalla\anaconda3\Lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "C:\Users\nalla\anaconda3\Lib\logging\handlers.py", line 179, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Users\nalla\anaconda3\Lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\nalla\\Downloads\\api_log.log' -> 'C:\\Users\\nalla\\Downloads\\api_log.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#     app.start()
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 711, in start
#     self.io_loop.start()
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\nalla\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Users\nalla\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Users\nalla\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 411, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 531, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3006, in run_cell
#     result = self._run_cell(
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3061, in _run_cell
#     result = runner(coro)
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3266, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3445, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\nalla\AppData\Local\Temp\ipykernel_3724\4067550638.py", line 79, in <module>
#     main()
#   File "C:\Users\nalla\AppData\Local\Temp\ipykernel_3724\4067550638.py", line 62, in main
#     all_data = get_all_data(api_url, headers)
#   File "C:\Users\nalla\AppData\Local\Temp\ipykernel_3724\4067550638.py", line 35, in get_all_data
#     response = requests.get(api_url, headers=headers)
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\requests\api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\requests\api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\requests\sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\requests\sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\requests\adapters.py", line 486, in send
#     resp = conn.urlopen(
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 714, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 473, in _make_request
#     log.debug(
# Message: '%s://%s:%s "%s %s %s" %s %s'
# Arguments: ('https', 'usflearn.instructure.com', 443, 'GET', '/api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkFsbW9uLCBKYWlkZW4iLDQyMjYzMDM5XQ&per_page=10', 'HTTP/1.1', 200, None)
# 2024-03-29 15:58:47,391 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\nalla\anaconda3\Lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "C:\Users\nalla\anaconda3\Lib\logging\handlers.py", line 179, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Users\nalla\anaconda3\Lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\nalla\\Downloads\\api_log.log' -> 'C:\\Users\\nalla\\Downloads\\api_log.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#     app.start()
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 711, in start
#     self.io_loop.start()
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\nalla\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Users\nalla\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Users\nalla\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 411, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 531, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3006, in run_cell
#     result = self._run_cell(
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3061, in _run_cell
#     result = runner(coro)
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3266, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3445, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\nalla\AppData\Local\Temp\ipykernel_3724\4067550638.py", line 79, in <module>
#     main()
#   File "C:\Users\nalla\AppData\Local\Temp\ipykernel_3724\4067550638.py", line 62, in main
#     all_data = get_all_data(api_url, headers)
#   File "C:\Users\nalla\AppData\Local\Temp\ipykernel_3724\4067550638.py", line 35, in get_all_data
#     response = requests.get(api_url, headers=headers)
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\requests\api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\requests\api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\requests\sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\requests\sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\requests\adapters.py", line 486, in send
#     resp = conn.urlopen(
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     conn = self._get_conn(timeout=pool_timeout)
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 298, in _get_conn
#     return conn or self._new_conn()
#   File "C:\Users\nalla\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 1014, in _new_conn
#     log.debug(
# Message: 'Starting new HTTPS connection (%d): %s:%s'
# Arguments: (1, 'usflearn.instructure.com', 443)
# 2024-03-29 15:58:47,956 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkFuZGVyc29uLCBCZW5qYW1pbiIsNDI0NTM2MDFd&per_page=10 HTTP/1.1" 200 None
# 2024-03-29 15:58:47,966 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-03-29 15:58:48,672 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkFzaGxleSwgVGhvbWFzIiw0MjAzNDg2N10&per_page=10 HTTP/1.1" 200 None
# 2024-03-29 15:58:48,682 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-03-29 15:58:49,290 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkJhaXJkLCBNYWRpbHlubiIsNDIyOTQ2MzFd&per_page=10 HTTP/1.1" 200 None
# 2024-03-29 15:58:49,298 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-03-29 15:58:49,902 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkJhdGlzdGEsIEx1aXMiLDQyMzg1MDg3XQ&per_page=10 HTTP/1.1" 200 None
# 2024-03-29 15:58:49,910 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-03-29 15:58:50,619 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkJsYW5jLCBKZW5pcXVlIiw0MjI1Nzc4N10&per_page=10 HTTP/1.1" 200 None
# 2024-03-29 15:58:50,629 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-03-29 15:58:51,130 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkJyZW1vbnQsIFR5bGVyIiw0MjUwOTA0N10&per_page=10 HTTP/1.1" 200 None
# 2024-03-29 15:58:51,140 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-03-29 15:58:51,641 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkJ1cm5ldHQsIEtlZGlzdCIsNDI2MTE4NzNd&per_page=10 HTTP/1.1" 200 None
# 2024-03-29 15:58:51,650 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-03-29 15:58:52,156 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkNhdmFuLCBUcmF2aXMiLDQyMzIwNzAzXQ&per_page=10 HTTP/1.1" 200 None
# 2024-03-29 15:58:52,168 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-03-29 15:58:52,872 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkNobywgQ2hyaXN0aWFuIiw0MjI5NTc1N10&per_page=10 HTTP/1.1" 200 None
# 2024-03-29 15:58:52,885 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-03-29 15:58:53,383 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkNvaG4sIFBhaWdlIiw0MjE4MTI1OV0&per_page=10 HTTP/1.1" 200 None
# 2024-03-29 15:58:53,394 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-03-29 15:58:53,998 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkNvc3RhIERhIFNpbHZhLCBBbGxhbiBKdW5pb3IiLDQyMjU5OTc1XQ&per_page=10 HTTP/1.1" 200 None
# 2024-03-29 15:58:54,008 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-03-29 15:58:54,720 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkN1YmlsbG9zLCBCcmFuZG9uIiw0MjM4MjI0NV0&per_page=10 HTTP/1.1" 200 None
# 2024-03-29 15:58:54,733 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-03-29 15:58:55,329 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkRhbWlhbmFraXMsIEFuYXN0YXNpb3MiLDQyMjYzMDA5XQ&per_page=10 HTTP/1.1" 200 None
# 2024-03-29 15:58:55,340 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-03-29 15:58:55,955 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkRlbGFuZXksIFNlYW4iLDQyMjk3NTI1XQ&per_page=10 HTTP/1.1" 200 None
# 2024-03-29 15:58:55,966 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-03-29 15:58:56,762 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkRpc2Fycm8sIEVtbWEiLDQyNTk3NDc1XQ&per_page=10 HTTP/1.1" 200 None
# 2024-03-29 15:58:56,776 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-03-29 15:58:57,596 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkRyYXBlciwgSGFsZXkiLDQyMjkyMjMzXQ&per_page=10 HTTP/1.1" 200 None
# 2024-03-29 15:58:57,608 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-03-29 15:58:58,673 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsIkVsbGVuYmFjaywgTHVrZSIsNDIzNDM2MjFd&per_page=10 HTTP/1.1" 200 None
# 2024-03-29 15:58:58,684 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-03-29 15:58:59,250 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJTdHVkZW50RW5yb2xsbWVudCIsI
0&per_page=10 HTTP/1.1" 200 None
# 2024-03-29 15:59:32,917 - DEBUG - Starting new HTTPS connection (1): usflearn.instructure.com:443
# 2024-03-29 15:59:33,167 - DEBUG - https://usflearn.instructure.com:443 "GET /api/v1/courses/1857108/enrollments?page=bookmark:WyJUZWFjaGVyRW5yb2xsbWVudCIsIldhbHBvbGUgKEFkbWluKSwgRGVubmlzIiw0MTkzOTM4NV0&per_page=10 HTTP/1.1" 200 None
# 2024-03-29 15:59:33,179 - INFO - No more records to retrieve. Stopping pagination.
# 2024-03-29 15:59:33,182 - INFO - API called 75 times
# 2024-03-29 15:59:33,199 - INFO - Data fetched successfully and saved to DataFrame.
# 2024-03-29 15:59:33,885 - INFO - Data saved to 'C:\Users\nalla\Downloads\Mohan\data1.xlsx'.
#          id  user_id  course_id                type            created_at  \
# 0  42697283  4638795    1857108  DesignerEnrollment  2024-01-08T20:22:12Z
# 1  42066599  4959011    1857108   StudentEnrollment  2023-10-31T05:42:10Z
# 2  42337449  4940043    1857108   StudentEnrollment  2023-11-19T06:42:02Z
# 3  42449855  4836803    1857108   StudentEnrollment  2023-12-08T20:23:59Z
# 4  42050207  4853363    1857108   StudentEnrollment  2023-10-30T23:26:20Z
#
#              updated_at associated_user_id start_at end_at  course_section_id  \
# 0  2024-01-08T20:37:03Z               None     None   None            2039727
# 1  2023-12-12T19:57:37Z               None     None   None            2039735
# 2  2023-12-12T19:50:37Z               None     None   None            2039733
# 3  2023-12-12T19:53:30Z               None     None   None            2039741
# 4  2023-12-12T19:50:37Z               None     None   None            2039733
#
#    ...  total_activity_time  sis_account_id   sis_course_id  \
# 0  ...                  423          BU.ISM  CGS2100.001S24
# 1  ...                 4765          BU.ISM  CGS2100.001S24
# 2  ...                28889          BU.ISM  CGS2100.001S24
# 3  ...                26267          BU.ISM  CGS2100.001S24
# 4  ...                 9092          BU.ISM  CGS2100.001S24
#
#   course_integration_id  sis_section_id section_integration_id sis_user_id  \
# 0                  None  CGS2100.001S24                   None   U64940243
# 1                  None  CGS2100.008S24                   None   U87546613
# 2                  None  CGS2100.006S24                   None   U30443576
# 3                  None  CGS2100.007S24                   None   U97733899
# 4                  None  CGS2100.006S24                   None   U67196743
#
#                                             html_url  \
# 0  https://usflearn.instructure.com/courses/18571...
# 1  https://usflearn.instructure.com/courses/18571...
# 2  https://usflearn.instructure.com/courses/18571...
# 3  https://usflearn.instructure.com/courses/18571...
# 4  https://usflearn.instructure.com/courses/18571...
#
#                                                 user  \
# 0  {'id': 4638795, 'name': 'Tess Crowder', 'creat...
# 1  {'id': 4959011, 'name': 'Janette Aarnio', 'cre...
# 2  {'id': 4940043, 'name': 'Taline Abadjian', 'cr...
# 3  {'id': 4836803, 'name': 'Trinity Abanid', 'cre...
# 4  {'id': 4853363, 'name': 'Steven Abdalla', 'cre...
#
#                                               grades
# 0                                                NaN
# 1  {'html_url': 'https://usflearn.instructure.com...
# 2  {'html_url': 'https://usflearn.instructure.com...
# 3  {'html_url': 'https://usflearn.instructure.com...
# 4  {'html_url': 'https://usflearn.instructure.com...
#
# [5 rows x 27 columns]
